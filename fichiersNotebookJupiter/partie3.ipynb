# %% [markdown]
# ***PROJET PYTHON***

# %% [markdown]
# **Partie 3**

# %%
import requests
def get_page(link):
    code_page = requests.get(link)
    return code_page.text

# %%
get_page('https://fr.wikipedia.org/wiki/Python_(langage)')
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="fr" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Python (langage) — Wikipédia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janvier","février","mars","avril","mai","juin","juillet","août","septembre","octobre","novembre","décembre"],"wgRequestId":"8807acbe-fc56-41f0-a626-d4001346d943","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Python_(langage)","wgTitle":"Python (langage)","wgCurRevisionId":182597028,"wgRevisionId":182597028,"wgArticleId":2340,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Page utilisant P348","Page utilisant P856","Page utilisant P1195","Article utilisant une Infobox","Article contenant un appel à traduction en anglais","Article avec une section vide ou incomplète","Catégorie Commons avec lien local identique sur Wikidata",\n"Portail:Informatique/Articles liés","Portail:Technologies/Articles liés","Portail:Sciences/Articles liés","Portail:Logiciels libres/Articles liés","Portail:Logiciel/Articles liés","Portail:Programmation informatique/Articles liés","Bon article en arabe","Bon article en allemand","Bon article en anglais","Python","Langage de programmation","Langage impératif","Langage fonctionnel","Langage orienté objet","Langage de script","Logiciel libre sous licence PSFL"],"wgPageContentLanguage":"fr","wgPageContentModel":"wikitext","wgRelevantPageName":"Python_(langage)","wgRelevantArticleId":2340,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":8,"wgVisualEditor":{"pageLanguageCode":"fr","pageLanguageDir":"ltr","pageVariantFallbacks":"fr"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},\n"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"français","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!0,"wgGELinkRecommendationsFrontendEnabled":!1,"wgWikibaseItemId":"Q28865"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.pygments":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter",\n"mediawiki.toc","skins.vector.js","ext.gadget.ArchiveLinks","ext.gadget.MonobookToolbarStandard","ext.gadget.Wdsearch","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});mw.user.options.set({"variant":"fr"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=fr&amp;modules=ext.cite.styles%7Cext.pygments%2CwikimediaBadges%7Cext.uls.in ...

# %%
import requests
import re
def get_emails(link):
    text = get_page(link)
    result = re.compile('([\w\.\-]+@[\w\.\-]+)').findall(text)
    return result

# %%
get_emails('https://fr.wikipedia.org/wiki/Python_(langage)')
# Out:
# ['user.options@1hzgi', 'python-committers@python.org']

# %%
import requests
import re
def get_urls(link):
        text = get_page(link)
        result = re.compile('(\w+)://([\w\-\.]+)/(\w+).(\w+)').findall(text)
        return result

# %%
get_urls('https://fr.wikipedia.org/wiki/Python_(langage)')
# Out:
# [('https', 'fr.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'www.wikidata.org', 'wiki', 'Special'),
#  ('https', 'commons.wikimedia.org', 'wiki', 'Category'),
#  ('https', 'fr.wikibooks.org', 'wiki', 'Programmation_Python'),
#  ('https', 'fr.wikiversity.org', 'wiki', 'Python'),
#  ('https', 'af.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'als.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'an.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ar.wikipedia.org', 'wi', 'i'),
#  ('https', 'as.wikipedia.org', 'wi', 'i'),
#  ('https', 'ast.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'az.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'azb.wikipedia.org', 'wi', 'i'),
#  ('https', 'ban.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'be.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'bg.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'bh.wikipedia.org', 'wi', 'i'),
#  ('https', 'bn.wikipedia.org', 'wi', 'i'),
#  ('https', 'bs.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'bug.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ca.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ceb.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'ckb.wikipedia.org', 'wi', 'i'),
#  ('https', 'cs.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'cy.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'da.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'de.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'el.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'eo.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'es.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'et.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'eu.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'fa.wikipedia.org', 'wi', 'i'),
#  ('https', 'fi.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'fj.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'gl.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'gu.wikipedia.org', 'wi', 'i'),
#  ('https', 'he.wikipedia.org', 'wi', 'i'),
#  ('https', 'hi.wikipedia.org', 'wi', 'i'),
#  ('https', 'hr.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'hu.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'hy.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ia.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'id.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'is.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'it.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ja.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'jbo.wikipedia.org', 'wiki', 'paiton'),
#  ('https', 'ka.wikipedia.org', 'wi', 'i'),
#  ('https', 'kk.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'km.wikipedia.org', 'wi', 'i'),
#  ('https', 'ko.wikipedia.org', 'wi', 'i'),
#  ('https', 'ku.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'ky.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'la.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'lmo.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'lt.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'lv.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'mk.wikipedia.org', 'wi', 'i'),
#  ('https', 'ml.wikipedia.org', 'wi', 'i'),
#  ('https', 'mn.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'mr.wikipedia.org', 'wi', 'i'),
#  ('https', 'ms.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'my.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'nds.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'nl.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'nn.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'no.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'nqo.wikipedia.org', 'wi', 'i'),
#  ('https', 'or.wikipedia.org', 'wi', 'i'),
#  ('https', 'pa.wikipedia.org', 'wi', 'i'),
#  ('https', 'pl.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'pnb.wikipedia.org', 'wi', 'i'),
#  ('https', 'pt.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ro.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ru.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'sah.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'sat.wikipedia.org', 'wi', 'i'),
#  ('https', 'sco.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sh.wikipedia.org', 'wiki', 'Python_programski_jezik'),
#  ('https', 'shn.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'si.wikipedia.org', 'wi', 'i'),
#  ('https', 'simple.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sk.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sl.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sq.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'sr.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sv.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'sw.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'ta.wikipedia.org', 'wi', 'i'),
#  ('https', 'te.wikipedia.org', 'wi', 'i'),
#  ('https', 'tg.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'th.wikipedia.org', 'wi', 'i'),
#  ('https', 'tl.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'tr.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'tt.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ug.wikipedia.org', 'wi', 'i'),
#  ('https', 'uk.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'ur.wikipedia.org', 'wi', 'i'),
#  ('https', 'uz.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'vi.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'wa.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'war.wikipedia.org', 'wiki', 'Python_'),
#  ('https', 'wuu.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'zh.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'zh-min-nan.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'zh-yue.wikipedia.org', 'wiki', 'Python'),
#  ('https', 'www.wikidata.org', 'wiki', 'Special'),
#  ('https', 'www.wikidata.org', 'wiki', 'Q28865'),
#  ('https', 'www.wikidata.org', 'wiki', 'Q28865'),
#  ('https', 'www.wikidata.org', 'wiki', 'Q28865'),
#  ('https', 'www.wikidata.org', 'wiki', 'Q28865'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https',
#   'en.wikipedia.org',
#   'wiki',
#   'Corporation_for_National_Research_Initiatives'),
#  ('https', 'en.wikipedia.org', 'wiki', 'C3_linearization'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Pyglet'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Unladen_Swallow'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Math_Kernel_Library'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('http', 'python-history.blogspot.com', '2009', '01'),
#  ('https', 'blog.python.org', '2021', '05'),
#  ('https', 'www.python.org', 'psf', 'license'),
#  ('https', 'www.python.org', 'download', 'other'),
#  ('http', 'www.greenteapress.com', 'thinkpython', 'thinkCSpy'),
#  ('https', 'www.python.org', 'doc', 'faq'),
#  ('https', 'books.google.fr', 'books', 'id'),
#  ('https', 'www.python.org', 'doc', 'essays'),
#  ('http', 'svn.python.org', 'projects', 'python'),
#  ('https', 'groups.google.com', 'group', 'alt'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('http', 'grail.sourceforge.net', 'info', 'team'),
#  ('http', 'grail.sourceforge.net', 'info', 'papers'),
#  ('https', 'docs.python.org', 'lib', 'module'),
#  ('https', 'docs.python.org', '2', 'library'),
#  ('http', 'grail.sourceforge.net', 'info', 'diagram'),
#  ('http', 'grail.sourceforge.net', 'info', 'diagram'),
#  ('https', 'www.python.org', 'doc', 'essays'),
#  ('https', 'www.python.org', 'doc', 'essays'),
#  ('https', 'docs.python.org', '2', 'license'),
#  ('https', 'mail.python.org', 'pipermail', 'python'),
#  ('https', 'web.archive.org', 'web', '20031002184114'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'wiki.python.org', 'moin', 'Python3'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', '3', 'fr'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'pypi.python.org', 'pypi', 'traits'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('http', 'svn.pythonmac.org', 'py2app', 'py2app'),
#  ('http', 'svn.pythonmac.org', 'py2app', 'py2app'),
#  ('http', 'www.diveintopython3.net', 'your', 'first'),
#  ('https', 'docs.python.org', 'tut', 'node11'),
#  ('http', 'effbot.org', 'pyfaq', 'why'),
#  ('http', 'www.mactech.com', 'articles', 'mactech'),
#  ('https', 'dx.doi.org', '10', '1145'),
#  ('http', 'citeseerx.ist.psu.edu', 'viewdoc', 'summary'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('https', 'google.github.io', 'styleguide', 'pyguide'),
#  ('https', 'www.mail-archive.com', 'python', 'committers'),
#  ('https', 'discuss.python.org', 't', 'steering'),
#  ('https', 'www.python.org', 'about', 'quotes'),
#  ('http', 'www.oreillynet.com', 'onlamp', 'blog'),
#  ('http', 'resources.arcgis.com', 'en', 'communities'),
#  ('http', 'cache.media.education.gouv.fr', 'file', 'special_3_ESR'),
#  ('http', 'www.mines-ponts.fr', 'pages', 'upload'),
#  ('http', 'www.concours-centrale-supelec.fr', 'CentraleSupel', 'c'),
#  ('https', 'wiki.python.org', 'moin', 'PythonImplementations'),
#  ('https', 'code.google.com', 'p', 'shedskin'),
#  ('https', 'code.google.com', 'p', 'unladen'),
#  ('https', 'github.com', 'RustPython', 'RustPython'),
#  ('https', 'wiki.python.org', 'moin', 'PythonDistributions'),
#  ('http', 'www.activestate.com', 'activepyth', 'n'),
#  ('https', 'software.intel.com', 'en', 'us'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('http', 'www.python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('http', 'www.python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('http', 'www.python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('http', 'www.python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'download', 'releases'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'downloads', 'release'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', '3', '7'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'docs.python.org', 'fr', '3'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'docs.python.org', '3', 'whatsnew'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'python.org', 'download', 'releases'),
#  ('https', 'www.python.org', 'peps', 'pep'),
#  ('https', 'wiki.python.org', 'moin', 'Python2orPython3'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('http', 'intertwingly.net', 'blog', '2007'),
#  ('https', 'www.python.org', 'dev', 'peps'),
#  ('https', 'code.google.com', 'p', 'android'),
#  ('http', 'code.google.com', 'p', 'android'),
#  ('http', 'hg.microcode.ca', 'blackberry', 'py'),
#  ('http', 'peterhansen.ca', 'blog', 'blackberry'),
#  ('https', 'commons.wikimedia.org', 'wiki', 'Category'),
#  ('https', 'fr.wiktionary.org', 'wiki', 'Python'),
#  ('https', 'fr.wikiversity.org', 'wiki', 'Python'),
#  ('https', 'fr.wikibooks.org', 'wiki', 'Cat'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Grok_'),
#  ('https', 'en.wikipedia.org', 'wiki', 'Pylons_project'),
#  ('https', 'pypi.python.org', 'pypi', 'MySQL'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https', 'en.wikipedia.org', 'wiki', 'PyObjC'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https', 'fr.wikipedia.org', 'w', 'index'),
#  ('https', 'creativecommons.org', 'licenses', 'by'),
#  ('https', 'wikimediafoundation.org', 'wiki', 'Conditions_d'),
#  ('https', 'meta.wikimedia.org', 'wiki', 'Privacy_policy'),
#  ('https', 'www.mediawiki.org', 'wiki', 'Special'),
#  ('https', 'foundation.wikimedia.org', 'wiki', 'Cookie_statement')]

# %%
import requests
import re
def get_tables(link):
    text = get_page(link)
    liste = []
    balise = '<table>'
    if balise in text:
        liste.append(balise)
        return liste

# %%
get_tables('https://fr.wikipedia.org/wiki/Table_(base_de_donn%C3%A9es)')
